# %% [markdown]
# ## Load the Iris dataset into a pandas DataFrame

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: cycler>=0.10 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/riddhishganeshmahajan/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### 1. Find the mean and median of the 'sepal_length' column.

# %%
df.sepal_length.mean()
# Out:
# 5.843333333333334

# %%
df.sepal_length.median()
# Out:
# 5.8

# %% [markdown]
# #### Calculate the 75th percentile of the 'petal_width' column for each species in the Iris dataset.

# %%
df.petal_width.quantile(0.75)
# Out:
# 1.8

# %% [markdown]
# #### Create a new column in the Iris DataFrame called 'sepal_area', which is the product of 'sepal_length' and 'sepal_width'.

# %%
df['Sepal_area'] = df.sepal_length * df.sepal_width

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area
# 0         17.85
# 1         14.70
# 2         15.04
# 3         14.26
# 4         18.00
# ..          ...
# 145       20.10
# 146       15.75
# 147       19.50
# 148       21.08
# 149       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# #### Remove all rows in the Iris DataFrame where 'petal_length' is greater than twice the standard deviation of 'petal_length' for that species.

# %%
df[df.petal_length > 2*df.petal_length.std()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
#      Sepal_area
# 50        22.40
# 51        20.48
# 52        21.39
# 53        12.65
# 54        18.20
# ..          ...
# 145       20.10
# 146       15.75
# 147       19.50
# 148       21.08
# 149       17.70
#
# [95 rows x 6 columns]

# %%
filtered_data = df[df.petal_length <= 2*df.petal_length.std()]

# %%
filtered_data
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# 5            5.4          3.9           1.7          0.4      setosa
# 6            4.6          3.4           1.4          0.3      setosa
# 7            5.0          3.4           1.5          0.2      setosa
# 8            4.4          2.9           1.4          0.2      setosa
# 9            4.9          3.1           1.5          0.1      setosa
# 10           5.4          3.7           1.5          0.2      setosa
# 11           4.8          3.4           1.6          0.2      setosa
# 12           4.8          3.0           1.4          0.1      setosa
# 13           4.3          3.0           1.1          0.1      setosa
# 14           5.8          4.0           1.2          0.2      setosa
# 15           5.7          4.4           1.5          0.4      setosa
# 16           5.4          3.9           1.3          0.4      setosa
# 17           5.1          3.5           1.4          0.3      setosa
# 18           5.7          3.8           1.7          0.3      setosa
# 19           5.1          3.8           1.5          0.3      setosa
# 20           5.4          3.4           1.7          0.2      setosa
# 21           5.1          3.7           1.5          0.4      setosa
# 22           4.6          3.6           1.0          0.2      setosa
# 23           5.1          3.3           1.7          0.5      setosa
# 24           4.8          3.4           1.9          0.2      setosa
# 25           5.0          3.0           1.6          0.2      setosa
# 26           5.0          3.4           1.6          0.4      setosa
# 27           5.2          3.5           1.5          0.2      setosa
# 28           5.2          3.4           1.4          0.2      setosa
# 29           4.7          3.2           1.6          0.2      setosa
# 30           4.8          3.1           1.6          0.2      setosa
# 31           5.4          3.4           1.5          0.4      setosa
# 32           5.2          4.1           1.5          0.1      setosa
# 33           5.5          4.2           1.4          0.2      setosa
# 34           4.9          3.1           1.5          0.2      setosa
# 35           5.0          3.2           1.2          0.2      setosa
# 36           5.5          3.5           1.3          0.2      setosa
# 37           4.9          3.6           1.4          0.1      setosa
# 38           4.4          3.0           1.3          0.2      setosa
# 39           5.1          3.4           1.5          0.2      setosa
# 40           5.0          3.5           1.3          0.3      setosa
# 41           4.5          2.3           1.3          0.3      setosa
# 42           4.4          3.2           1.3          0.2      setosa
# 43           5.0          3.5           1.6          0.6      setosa
# 44           5.1          3.8           1.9          0.4      setosa
# 45           4.8          3.0           1.4          0.3      setosa
# 46           5.1          3.8           1.6          0.2      setosa
# 47           4.6          3.2           1.4          0.2      setosa
# 48           5.3          3.7           1.5          0.2      setosa
# 49           5.0          3.3           1.4          0.2      setosa
# 57           4.9          2.4           3.3          1.0  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 79           5.7          2.6           3.5          1.0  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
#
#     Sepal_area
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# 5        21.06
# 6        15.64
# 7        17.00
# 8        12.76
# 9        15.19
# 10       19.98
# 11       16.32
# 12       14.40
# 13       12.90
# 14       23.20
# 15       25.08
# 16       21.06
# 17       17.85
# 18       21.66
# 19       19.38
# 20       18.36
# 21       18.87
# 22       16.56
# 23       16.83
# 24       16.32
# 25       15.00
# 26       17.00
# 27       18.20
# 28       17.68
# 29       15.04
# 30       14.88
# 31       18.36
# 32       21.32
# 33       23.10
# 34       15.19
# 35       16.00
# 36       19.25
# 37       17.64
# 38       13.20
# 39       17.34
# 40       17.50
# 41       10.35
# 42       14.08
# 43       17.50
# 44       19.38
# 45       14.40
# 46       19.38
# 47       14.72
# 48       19.61
# 49       16.50
# 57       11.76
# 60       10.00
# 79       14.82
# 93       11.50
# 98       12.75

# %% [markdown]
# #### Normalize all numerical columns in the Iris DataFrame (except the 'species' column) using Min-Max scaling.

# %%
df1 = df.drop(columns=['species'])

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Sepal_area
# 0             5.1          3.5           1.4          0.2       17.85
# 1             4.9          3.0           1.4          0.2       14.70
# 2             4.7          3.2           1.3          0.2       15.04
# 3             4.6          3.1           1.5          0.2       14.26
# 4             5.0          3.6           1.4          0.2       18.00
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3       20.10
# 146           6.3          2.5           5.0          1.9       15.75
# 147           6.5          3.0           5.2          2.0       19.50
# 148           6.2          3.4           5.4          2.3       21.08
# 149           5.9          3.0           5.1          1.8       17.70
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Normalize_data = MinMaxScaler()

# %%
Normalize_data.fit(df1)
# Out:
# MinMaxScaler()

# %%
Normalize_data.transform(df1)
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667, 0.39210789],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667, 0.23476523],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667, 0.25174825],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667, 0.21278721],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667, 0.3996004 ],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     , 0.55244755],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333, 0.28171828],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667, 0.34965035],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667, 0.13786214],
#        [0.16666667, 0.45833333, 0.08474576, 0.        , 0.25924076],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667, 0.4985015 ],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667, 0.31568432],
#        [0.13888889, 0.41666667, 0.06779661, 0.        , 0.21978022],
#        [0.        , 0.41666667, 0.01694915, 0.        , 0.14485514],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667, 0.65934066],
#        [0.38888889, 1.        , 0.08474576, 0.125     , 0.75324675],
#        [0.30555556, 0.79166667, 0.05084746, 0.125     , 0.55244755],
#        [0.22222222, 0.625     , 0.06779661, 0.08333333, 0.39210789],
#        [0.38888889, 0.75      , 0.11864407, 0.08333333, 0.58241758],
#        [0.22222222, 0.75      , 0.08474576, 0.08333333, 0.46853147],
#        [0.30555556, 0.58333333, 0.11864407, 0.04166667, 0.41758242],
#        [0.22222222, 0.70833333, 0.08474576, 0.125     , 0.44305694],
#        [0.08333333, 0.66666667, 0.        , 0.04166667, 0.32767233],
#        [0.22222222, 0.54166667, 0.11864407, 0.16666667, 0.34115884],
#        [0.13888889, 0.58333333, 0.15254237, 0.04166667, 0.31568432],

#        [0.41666667, 0.29166667, 0.69491525, 0.75      , 0.28271728],
#        [0.69444444, 0.5       , 0.83050847, 0.91666667, 0.58741259],
#        [0.66666667, 0.54166667, 0.79661017, 1.        , 0.6048951 ],
#        [0.66666667, 0.41666667, 0.71186441, 0.91666667, 0.5044955 ],
#        [0.55555556, 0.20833333, 0.6779661 , 0.75      , 0.28721279],
#        [0.61111111, 0.41666667, 0.71186441, 0.79166667, 0.47452547],
#        [0.52777778, 0.58333333, 0.74576271, 0.91666667, 0.55344655],
#        [0.44444444, 0.41666667, 0.69491525, 0.70833333, 0.38461538]])

# %%
df_normalize = pd.DataFrame(Normalize_data.transform(df1) , columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
       'Sepal_area'])

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'Sepal_area'],
#       dtype='object')

# %%
df_normalize
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Sepal_area
# 0        0.222222     0.625000      0.067797     0.041667    0.392108
# 1        0.166667     0.416667      0.067797     0.041667    0.234765
# 2        0.111111     0.500000      0.050847     0.041667    0.251748
# 3        0.083333     0.458333      0.084746     0.041667    0.212787
# 4        0.194444     0.666667      0.067797     0.041667    0.399600
# ..            ...          ...           ...          ...         ...
# 145      0.666667     0.416667      0.711864     0.916667    0.504496
# 146      0.555556     0.208333      0.677966     0.750000    0.287213
# 147      0.611111     0.416667      0.711864     0.791667    0.474525
# 148      0.527778     0.583333      0.745763     0.916667    0.553447
# 149      0.444444     0.416667      0.694915     0.708333    0.384615
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
df_normalize.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### Find the three most common combinations of 'sepal_length', 'sepal_width', and 'petal_length' in the Iris dataset.

# %%
top_combination = df.groupby([ 'sepal_length', 'sepal_width', 'petal_length'])

# %%
top_combination = top_combination.size().reset_index(name = 'count')

# %%
top_combination.sort_values(by = 'count' , ascending=True).head(3)
# Out:
#      sepal_length  sepal_width  petal_length  count
# 0             4.3          3.0           1.1      1
# 103           6.3          3.4           5.6      1
# 102           6.3          3.3           6.0      1

# %% [markdown]
# #### Group the Iris DataFrame by 'species' and find the row with the highest 'sepal_width' for each group.

# %%
df.groupby(df.species).apply(lambda group: group[group['sepal_width'] == group['sepal_width'].max()]).reset_index(drop = True)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species  \
# 0           5.7          4.4           1.5          0.4      setosa
# 1           6.0          3.4           4.5          1.6  versicolor
# 2           7.7          3.8           6.7          2.2   virginica
# 3           7.9          3.8           6.4          2.0   virginica
#
#    Sepal_area
# 0       25.08
# 1       20.40
# 2       29.26
# 3       30.02

# %% [markdown]
# ####  Replace all negative values in the 'petal_width' column of the Iris DataFrame with the mean of the non-negative values in that column.

# %%
df[df.petal_width < 0]['petal_width']
# Out:
# nan

# %% [markdown]
# #### Calculate the correlation matrix for the 'sepal_length', 'sepal_width', 'petal_length', and 'petal_width' columns in the Iris dataset and find the feature with the highest absolute correlation with 'petal_width'

# %%
relation = df.corr()

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
feture_most_related = relation.petal_width.abs().idxmax()

# %%
feture_most_related
# Out:
# 'petal_width'
